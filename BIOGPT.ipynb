# %% [markdown]
# <a href="https://colab.research.google.com/github/Aminolroaya/Clinical_Notes_LLM/blob/main/BIOGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/pytorch/fairseq
# %cd fairseq
# !git checkout v0.12.0
# !pip install .
# !python setup.py build_ext --inplace
# %cd ..
# !pip install transformers
# !git clone https://github.com/moses-smt/mosesdecoder.git
# !export MOSES=${PWD}/mosesdecoder
# !git clone https://github.com/glample/fastBPE.git
# !export FASTBPE=${PWD}/fastBPE
# !pip install sacremoses
# !pip install scikit-learn
# %cd fastBPE
# %cd fastBPE
# !g++ -std=c++11 -pthread -O3 main.cc -IfastBPE -o fast
# %cd ..
# %cd ..
# !pip uninstall jax jaxlib
# !pip install jax jaxlib
# !pip install pandas
! pip install -U accelerate
! pip install -U transformers
# Out:
# Cloning into 'fairseq'...
# remote: Enumerating objects: 34769, done.
# remote: Total 34769 (delta 0), reused 0 (delta 0), pack-reused 34769
# Receiving objects: 100% (34769/34769), 24.99 MiB | 18.84 MiB/s, done.
# Resolving deltas: 100% (25234/25234), done.
# /content/fairseq
# Note: switching to 'v0.12.0'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false
#
# HEAD is now at 6795311b 0.12.0 release
# Processing /content/fairseq
#   Installing build dependencies ... done
# ...

# %%
from transformers import pipeline, set_seed
from transformers import BioGptTokenizer, BioGptForCausalLM
#define model and tokenizer
model = BioGptForCausalLM.from_pretrained("microsoft/biogpt")
tokenizer = AutoTokenizer.from_pretrained("microsoft/biogpt")

# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/Aminolroaya/Clinical_Notes_LLM/f3268b77b79ab94dc080ba01df9cd68734088119/patient_notes.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-7bfe5d051b35> in <cell line: 4>()
#       2 data = pd.read_csv("https://raw.githubusercontent.com/Aminolroaya/Clinical_Notes_LLM/f3268b77b79ab94dc080ba01df9cd68734088119/patient_notes.csv")
#       3 data
# ----> 4 tokenized_data=data.applymap(tokenizer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in applymap(self, func, na_action, **kwargs)
#    9651             return lib.map_infer(x.astype(object)._values, func, ignore_na=ignore_na)
#    9652
# -> 9653         return self.apply(infer).__finalize__(self, "applymap")
#    9654
#    9655     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    9566             kwargs=kwargs,
# ...

# %%
tokenized_data=data.applymap(tokenizer)

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
from transformers import TrainingArguments, Trainer

training_args = TrainingArguments(output_dir="test_trainer", evaluation_strategy="epoch")

# %%
from torch import nn
from transformers import Trainer
from transformers import TrainingArguments, Trainer
import accelerate

trainer = Trainer(
    model=model,
    train_dataset=tokenized_data.iloc[0])
